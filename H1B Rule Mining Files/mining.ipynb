# %%
import mlxtend
import pandas as pd
import numpy as np
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# %%
df = pd.read_csv("filtered_h1b.csv")

# %%
rule_mining_1 = ['CASE_STATUS','SOC_TITLE','FULL_TIME_POSITION','H_1B_DEPENDENT','PUBLIC_DISCLOSURE']

# %%
df1 = df[rule_mining_1]

# %%
df1
# Out:
#                  CASE_STATUS                                   SOC_TITLE  \
# 0      Certified - Withdrawn                Operations Research Analysts
# 1      Certified - Withdrawn                         Management Analysts
# 2      Certified - Withdrawn   Computer and Information Systems Managers
# 3      Certified - Withdrawn                   Computer Systems Analysts
# 4                  Withdrawn             General and Operations Managers
# ...                      ...                                         ...
# 80044  Certified - Withdrawn                        Electrical Engineers
# 80045  Certified - Withdrawn                        Electrical Engineers
# 80046              Withdrawn  Business Operations Specialists, All Other
# 80047  Certified - Withdrawn           Software Developers, Applications
# 80048  Certified - Withdrawn           Software Developers, Applications
#
#       FULL_TIME_POSITION H_1B_DEPENDENT                 PUBLIC_DISCLOSURE
# 0                      Y             No                 Disclose Business
# 1                      Y             No                 Disclose Business
# 2                      Y            NaN                 Disclose Business
# 3                      Y            Yes                 Disclose Business
# 4                      Y            NaN                 Disclose Business
# ...                  ...            ...                               ...
# 80044                  Y             No                 Disclose Business
# 80045                  Y             No                 Disclose Business
# 80046                  Y            NaN  Disclose Business and Employment
# 80047                  Y             No                 Disclose Business
# 80048                  Y             No                 Disclose Business
#
# [80049 rows x 5 columns]

# %%
cert = df1[(df1['CASE_STATUS']=='Certified - Withdrawn') | (df1['CASE_STATUS']=='Certified') ]

# %%
cert
# Out:
#                  CASE_STATUS                                  SOC_TITLE  \
# 0      Certified - Withdrawn               Operations Research Analysts
# 1      Certified - Withdrawn                        Management Analysts
# 2      Certified - Withdrawn  Computer and Information Systems Managers
# 3      Certified - Withdrawn                  Computer Systems Analysts
# 6      Certified - Withdrawn                       Computer Programmers
# ...                      ...                                        ...
# 80043              Certified                  Computer Systems Analysts
# 80044  Certified - Withdrawn                       Electrical Engineers
# 80045  Certified - Withdrawn                       Electrical Engineers
# 80047  Certified - Withdrawn          Software Developers, Applications
# 80048  Certified - Withdrawn          Software Developers, Applications
#
#       FULL_TIME_POSITION H_1B_DEPENDENT  PUBLIC_DISCLOSURE
# 0                      Y             No  Disclose Business
# 1                      Y             No  Disclose Business
# 2                      Y            NaN  Disclose Business
# 3                      Y            Yes  Disclose Business
# 6                      Y            Yes  Disclose Business
# ...                  ...            ...                ...
# 80043                  Y            Yes  Disclose Business
# 80044                  Y             No  Disclose Business
# 80045                  Y             No  Disclose Business
# 80047                  Y             No  Disclose Business
# 80048                  Y             No  Disclose Business
#
# [78373 rows x 5 columns]

# %%
transactions = df1.groupby(['SOC_TITLE','FULL_TIME_POSITION','H_1B_DEPENDENT',
       'PUBLIC_DISCLOSURE']).size().reset_index(name='count')

# %%
transactions
# Out:
#                                SOC_TITLE FULL_TIME_POSITION H_1B_DEPENDENT  \
# 0               Accountants and Auditors                  N             No
# 1               Accountants and Auditors                  N             No
# 2               Accountants and Auditors                  N            Yes
# 3               Accountants and Auditors                  Y             No
# 4               Accountants and Auditors                  Y             No
# ..                                   ...                ...            ...
# 661  Web and Digital Interface Designers                  Y             No
# 662  Web and Digital Interface Designers                  Y             No
# 663  Web and Digital Interface Designers                  Y             No
# 664  Web and Digital Interface Designers                  Y            Yes
# 665  Web and Digital Interface Designers                  Y            Yes
#
#                     PUBLIC_DISCLOSURE  count
# 0                   Disclose Business     62
# 1                 Disclose Employment      6
# 2                 Disclose Employment      1
# 3                   Disclose Business   1734
# 4    Disclose Business and Employment     56
# ..                                ...    ...
# 661                 Disclose Business    138
# 662  Disclose Business and Employment      6
# 663               Disclose Employment     14
# 664                 Disclose Business    121
# 665  Disclose Business and Employment      1
#
# [666 rows x 5 columns]

# %%
transaction_list = []

for index, row in transactions.iterrows():
    transaction_list.append([row['SOC_TITLE'], row['FULL_TIME_POSITION'],row['H_1B_DEPENDENT'],row['PUBLIC_DISCLOSURE']])

# %%
te = TransactionEncoder()

# %%
te_ary = te.fit(transaction_list).transform(transaction_list)

# %%
df_encoded = pd.DataFrame(te_ary, columns=te.columns_)

# %%
# Get frequent itemsets
frequent_itemsets1 = apriori(df_encoded, min_support=0.5, use_colnames=True)

# %%
frequent_itemsets1
# Out:
#     support             itemsets
# 0  0.504505  (Disclose Business)
# 1  0.732733                 (No)
# 2  0.684685                  (Y)

# %%
rules1 = association_rules(frequent_itemsets1, metric="confidence", min_threshold=0.1)

# %%
rules1
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction, zhangs_metric]
# Index: []

# %%
# Get frequent itemsets
frequent_itemsets2 = apriori(df_encoded, min_support=0.3, use_colnames=True)

# %%
frequent_itemsets2
# Out:
#     support                 itemsets
# 0  0.504505      (Disclose Business)
# 1  0.315315                      (N)
# 2  0.732733                     (No)
# 3  0.684685                      (Y)
# 4  0.315315  (No, Disclose Business)
# 5  0.480480                  (No, Y)

# %%
rules2 = association_rules(frequent_itemsets2, metric="confidence", min_threshold=0.1)

# %%
rules2
# Out:
#            antecedents          consequents  antecedent support  \
# 0                 (No)  (Disclose Business)            0.732733
# 1  (Disclose Business)                 (No)            0.504505
# 2                 (No)                  (Y)            0.732733
# 3                  (Y)                 (No)            0.684685
#
#    consequent support   support  confidence      lift  leverage  conviction  \
# 0            0.504505  0.315315    0.430328  0.852971 -0.054352    0.869791
# 1            0.732733  0.315315    0.625000  0.852971 -0.054352    0.712713
# 2            0.684685  0.480480    0.655738  0.957722 -0.021210    0.915916
# 3            0.732733  0.480480    0.701754  0.957722 -0.021210    0.896131
#
#    zhangs_metric
# 0      -0.392077
# 1      -0.258094
# 2      -0.141755
# 3      -0.122807

# %%
# Get frequent itemsets
frequent_itemsets3 = apriori(df_encoded, min_support=0.1, use_colnames=True)

# %%
frequent_itemsets3
# Out:
#      support                                   itemsets
# 0   0.504505                        (Disclose Business)
# 1   0.249249         (Disclose Business and Employment)
# 2   0.246246                      (Disclose Employment)
# 3   0.315315                                        (N)
# 4   0.732733                                       (No)
# 5   0.684685                                        (Y)
# 6   0.267267                                      (Yes)
# 7   0.207207                     (Disclose Business, N)
# 8   0.315315                    (No, Disclose Business)
# 9   0.297297                     (Disclose Business, Y)
# 10  0.189189                   (Disclose Business, Yes)
# 11  0.204204     (No, Disclose Business and Employment)
# 12  0.196697      (Y, Disclose Business and Employment)
# 13  0.213213                  (No, Disclose Employment)
# 14  0.190691                   (Disclose Employment, Y)
# 15  0.252252                                    (No, N)
# 16  0.480480                                    (No, Y)
# 17  0.204204                                   (Yes, Y)
# 18  0.148649                 (No, Disclose Business, N)
# 19  0.166667                 (No, Disclose Business, Y)
# 20  0.130631                (Disclose Business, Yes, Y)
# 21  0.154655  (No, Y, Disclose Business and Employment)
# 22  0.159159               (No, Disclose Employment, Y)

# %%
rules3 = association_rules(frequent_itemsets3, metric="confidence", min_threshold=0.1)

# %%
rules3
# Out:
#                                antecedents  \
# 0                      (Disclose Business)
# 1                                      (N)
# 2                                     (No)
# 3                      (Disclose Business)
# 4                      (Disclose Business)
# 5                                      (Y)
# 6                      (Disclose Business)
# 7                                    (Yes)
# 8                                     (No)
# 9       (Disclose Business and Employment)
# 10                                     (Y)
# 11      (Disclose Business and Employment)
# 12                                    (No)
# 13                   (Disclose Employment)
# 14                   (Disclose Employment)
# 15                                     (Y)
# 16                                    (No)
# 17                                     (N)
# 18                                    (No)
# 19                                     (Y)
# 20                                   (Yes)
# 21                                     (Y)
# 22                 (No, Disclose Business)
# 23                                 (No, N)
# 24                  (Disclose Business, N)
# 25                                    (No)
# 26                     (Disclose Business)
# 27                                     (N)
# 28                 (No, Disclose Business)
# 29                                 (No, Y)
# 30                  (Disclose Business, Y)
# 31                                    (No)
# 32                     (Disclose Business)
# 33                                     (Y)
# 34                (Disclose Business, Yes)
# 35                  (Disclose Business, Y)
# 36                                (Y, Yes)
# 37                     (Disclose Business)
# 38                                   (Yes)
# 39                                     (Y)
# 40                                 (No, Y)
# 41  (No, Disclose Business and Employment)
# 42   (Y, Disclose Business and Employment)
# 43                                    (No)
# 44                                     (Y)
# 45      (Disclose Business and Employment)
# 46               (No, Disclose Employment)
# 47                                 (No, Y)
# 48                (Y, Disclose Employment)
# 49                                    (No)
# 50                   (Disclose Employment)
# 51                                     (Y)
#
#                                consequents  antecedent support  \
# 0                                      (N)            0.504505
# 1                      (Disclose Business)            0.315315
# 2                      (Disclose Business)            0.732733
# 3                                     (No)            0.504505
# 4                                      (Y)            0.504505
# 5                      (Disclose Business)            0.684685
# 6                                    (Yes)            0.504505
# 7                      (Disclose Business)            0.267267
# 8       (Disclose Business and Employment)            0.732733
# 9                                     (No)            0.249249
# 33      -0.483652
# 34       0.010345
# 35       0.557471
# 36       0.265582
# 37       0.426541
# 38       0.534624
# 39       0.026601
# 40       0.434312
# 41       0.120572
# 42       0.084747
# 43       0.254718
# 44       0.304300
# 45       0.300544
# 46       0.105214
# 47       0.493947
# 48       0.150873
# 49       0.456858
# 50       0.340450
# 51       0.262534

# %%
# Get frequent itemsets
frequent_itemsets4 = apriori(df_encoded, min_support=0.05, use_colnames=True)

# %%
frequent_itemsets4
# Out:
#      support                                   itemsets
# 0   0.504505                        (Disclose Business)
# 1   0.249249         (Disclose Business and Employment)
# 2   0.246246                      (Disclose Employment)
# 3   0.315315                                        (N)
# 4   0.732733                                       (No)
# 5   0.684685                                        (Y)
# 6   0.267267                                      (Yes)
# 7   0.207207                     (Disclose Business, N)
# 8   0.315315                    (No, Disclose Business)
# 9   0.297297                     (Disclose Business, Y)
# 10  0.189189                   (Disclose Business, Yes)
# 11  0.052553      (N, Disclose Business and Employment)
# 12  0.204204     (No, Disclose Business and Employment)
# 13  0.196697      (Y, Disclose Business and Employment)
# 14  0.055556                   (N, Disclose Employment)
# 15  0.213213                  (No, Disclose Employment)
# 16  0.190691                   (Disclose Employment, Y)
# 17  0.252252                                    (No, N)
# 18  0.063063                                   (N, Yes)
# 19  0.480480                                    (No, Y)
# 20  0.204204                                   (Yes, Y)
# 21  0.148649                 (No, Disclose Business, N)
# 22  0.058559                (Disclose Business, N, Yes)
# 23  0.166667                 (No, Disclose Business, Y)
# 24  0.130631                (Disclose Business, Yes, Y)
# 25  0.154655  (No, Y, Disclose Business and Employment)
# 26  0.054054               (No, N, Disclose Employment)
# 27  0.159159               (No, Disclose Employment, Y)

# %%
rules4 = association_rules(frequent_itemsets4, metric="confidence", min_threshold=0.1)

# %%
rules4
# Out:
#                  antecedents                consequents  antecedent support  \
# 0        (Disclose Business)                        (N)            0.504505
# 1                        (N)        (Disclose Business)            0.315315
# 2                       (No)        (Disclose Business)            0.732733
# 3        (Disclose Business)                       (No)            0.504505
# 4        (Disclose Business)                        (Y)            0.504505
# ..                       ...                        ...                 ...
# 64                   (No, Y)      (Disclose Employment)            0.480480
# 65  (Y, Disclose Employment)                       (No)            0.190691
# 66                      (No)   (Y, Disclose Employment)            0.732733
# 67     (Disclose Employment)                    (No, Y)            0.246246
# 68                       (Y)  (No, Disclose Employment)            0.684685
#
#     consequent support   support  confidence      lift  leverage  conviction  \
# 0             0.315315  0.207207    0.410714  1.302551  0.048129    1.161889
# 1             0.504505  0.207207    0.657143  1.302551  0.048129    1.445195
# 2             0.504505  0.315315    0.430328  0.852971 -0.054352    0.869791
# 3             0.732733  0.315315    0.625000  0.852971 -0.054352    0.712713
# 4             0.684685  0.297297    0.589286  0.860667 -0.048129    0.767724
# ..                 ...       ...         ...       ...       ...         ...
# 64            0.246246  0.159159    0.331250  1.345198  0.040843    1.127108
# 65            0.732733  0.159159    0.834646  1.139086  0.019434    1.616331
# 66            0.190691  0.159159    0.217213  1.139086  0.019434    1.033882
# 67            0.480480  0.159159    0.646341  1.345198  0.040843    1.468986
# 68            0.213213  0.159159    0.232456  1.090252  0.013175    1.025071
#
#     zhangs_metric
# 0        0.468775
# 1        0.339245
# 2       -0.392077
# 3       -0.258094
# 4       -0.246262
# ..            ...
# 64       0.493947
# 65       0.150873
# 66       0.456858
# 67       0.340450
# 68       0.262534
#
# [69 rows x 10 columns]

# %%
frequent_itemsets5 = apriori(df_encoded, min_support=0.01, use_colnames=True)

# %%
frequent_itemsets5
# Out:
#      support                                    itemsets
# 0   0.012012                  (Accountants and Auditors)
# 1   0.015015            (Business Intelligence Analysts)
# 2   0.010511                          (Chief Executives)
# 3   0.010511               (Computer Network Architects)
# 4   0.012012           (Computer Occupations, All Other)
# ..       ...                                         ...
# 64  0.154655   (No, Y, Disclose Business and Employment)
# 65  0.042042  (Y, Yes, Disclose Business and Employment)
# 66  0.054054                (No, N, Disclose Employment)
# 67  0.159159                (No, Disclose Employment, Y)
# 68  0.031532               (Yes, Disclose Employment, Y)
#
# [69 rows x 2 columns]

# %%
rules5 = association_rules(frequent_itemsets5, metric="confidence", min_threshold=0.1)

# %%
rules5
# Out:
#                    antecedents               consequents  antecedent support  \
# 0          (Disclose Business)                       (N)            0.504505
# 1                          (N)       (Disclose Business)            0.315315
# 2                         (No)       (Disclose Business)            0.732733
# 3          (Disclose Business)                      (No)            0.504505
# 4          (Disclose Business)                       (Y)            0.504505
# ..                         ...                       ...                 ...
# 83  (Disclose Employment, Yes)                       (Y)            0.033033
# 84                    (Y, Yes)     (Disclose Employment)            0.204204
# 85    (Y, Disclose Employment)                     (Yes)            0.190691
# 86                       (Yes)  (Y, Disclose Employment)            0.267267
# 87       (Disclose Employment)                  (Y, Yes)            0.246246
#
#     consequent support   support  confidence      lift  leverage  conviction  \
# 0             0.315315  0.207207    0.410714  1.302551  0.048129    1.161889
# 1             0.504505  0.207207    0.657143  1.302551  0.048129    1.445195
# 2             0.504505  0.315315    0.430328  0.852971 -0.054352    0.869791
# 3             0.732733  0.315315    0.625000  0.852971 -0.054352    0.712713
# 4             0.684685  0.297297    0.589286  0.860667 -0.048129    0.767724
# ..                 ...       ...         ...       ...       ...         ...
# 83            0.684685  0.031532    0.954545  1.394139  0.008914    6.936937
# 84            0.246246  0.031532    0.154412  0.627062 -0.018753    0.891396
# 85            0.267267  0.031532    0.165354  0.618685 -0.019434    0.877897
# 86            0.190691  0.031532    0.117978  0.618685 -0.019434    0.917561
# 87            0.204204  0.031532    0.128049  0.627062 -0.018753    0.912661
#
#     zhangs_metric
# 0        0.468775
# 1        0.339245
# 2       -0.392077
# 3       -0.258094
# 4       -0.246262
# ..            ...
# 83       0.292369
# 84      -0.427705
# 85      -0.432319
# 86      -0.456858
# 87      -0.441039
#
# [88 rows x 10 columns]
